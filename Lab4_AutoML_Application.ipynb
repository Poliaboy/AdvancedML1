# %% [markdown]
# ## Lab 3: Introduction to AutoML Using TPOT

# %% [markdown]
# ### **Objective**:
# In this lab, you will explore Automated Machine Learning (AutoML), focusing on the TPOT library, which automates the process of feature selection, model selection, and hyperparameter optimization using genetic programming. By the end of this lab, you’ll understand how to leverage TPOT for automating the model building pipeline.
#
# ### Prerequisites:
#
# •	Basic knowledge of Machine Learning.
#
# •	Familiarity with supervised learning models and the concept of model evaluation metrics.
#
# •	Required Libraries: pandas, sklearn, TPOT.

# %% [markdown]
# ### **1. Introduction to AutoML and TPOT**
#
# AutoML helps automate the end-to-end process of applying machine learning models to real-world problems. It assists with tasks like:
#
# •	Preprocessing data.
#
# •	Selecting features.
#
# •	Tuning hyperparameters.
#
# •	Training models.
#
# TPOT (Tree-based Pipeline Optimization Tool) is a Python library that uses genetic programming to automate the machine learning pipeline. It automatically optimizes models and discovers the best pipeline for a given dataset.
#
# #### **Step 1.1: Install Required Libraries**

# %%
# Install TPOT (if not installed)
# %pip install tpot scikit-learn pandas
# Out:
# Collecting tpot
#   Downloading TPOT-0.12.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.16.3 in ./.venv/lib/python3.11/site-packages (from tpot) (2.1.2)
# Requirement already satisfied: scipy>=1.3.1 in ./.venv/lib/python3.11/site-packages (from tpot) (1.14.1)
# Collecting deap>=1.2 (from tpot)
#   Using cached deap-1.4.1-cp311-cp311-macosx_14_0_arm64.whl
# Collecting update-checker>=0.16 (from tpot)
#   Downloading update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: tqdm>=4.36.1 in ./.venv/lib/python3.11/site-packages (from tpot) (4.67.1)
# Collecting stopit>=1.1.1 (from tpot)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=0.13.2 in ./.venv/lib/python3.11/site-packages (from tpot) (1.4.2)
# Requirement already satisfied: xgboost>=1.1.0 in ./.venv/lib/python3.11/site-packages (from tpot) (2.1.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: requests>=2.3.0 in ./.venv/lib/python3.11/site-packages (from update-checker>=0.16->tpot) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2024.8.30)
# Downloading TPOT-0.12.2-py3-none-any.whl (87 kB)
# Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (pyproject.toml) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=bcadad4a3504d97ed251f2fae0448617fd36e2f3ab382a2dc664f9109cf392cb
#   Stored in directory: /Users/alexs/Library/Caches/pip/wheels/da/77/2d/adbc56bc4db95ad80c6d4e71cd69e2d9d122174904342e3f7f
# Successfully built stopit
# Installing collected packages: stopit, deap, update-checker, tpot
# Successfully installed deap-1.4.1 stopit-1.1.2 tpot-0.12.2 update-checker-0.18.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **2. Load and Explore the Dataset**
#
# In this step, we’ll load a dataset to be used with AutoML. We’ll work with the breast cancer dataset from sklearn.
#
# #### **Step 2.1: Load the Dataset**

# %%
# Import necessary libraries
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load the breast cancer dataset
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Display the first few rows of the dataset
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 149        13.74         17.91           88.12      585.0          0.07944
# 124        13.37         16.39           86.10      553.5          0.07115
# 421        14.69         13.98           98.22      656.1          0.10310
# 195        12.91         16.33           82.53      516.4          0.07941
# 545        13.62         23.23           87.19      573.2          0.09246
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 149           0.06376         0.02881              0.01329         0.1473
# 124           0.07325         0.08092              0.02800         0.1422
# 421           0.18360         0.14500              0.06300         0.2086
# 195           0.05366         0.03873              0.02377         0.1829
# 545           0.06747         0.02974              0.02443         0.1664
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 149                 0.05580  ...         15.34          22.46
# 124                 0.05823  ...         14.26          22.75
# 421                 0.07406  ...         16.46          18.34
# 195                 0.05667  ...         13.88          22.00
# 545                 0.05801  ...         15.35          29.09
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 149            97.19       725.9           0.09711             0.1824
# 124            91.99       632.1           0.10250             0.2531
# 421           114.10       809.2           0.13120             0.3635
# 195            90.81       600.6           0.10970             0.1506
# 545            97.58       729.8           0.12160             0.1517
#
#      worst concavity  worst concave points  worst symmetry  \
# 149           0.1564               0.06019          0.2350
# 124           0.3308               0.08978          0.2048
# 421           0.3219               0.11080          0.2827
# 195           0.1764               0.08235          0.3024
# 545           0.1049               0.07174          0.2642
#
#      worst fractal dimension
# 149                  0.07014
# 124                  0.07628
# 421                  0.09208
# 195                  0.06949
# 545                  0.06953
#
# [5 rows x 30 columns]

# %% [markdown]
# #### **Step 2.2: Check Dataset Information**

# %%
# Check the shape of the dataset
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)

# Check for missing values
print("\nMissing values:\n", X_train.isnull().sum())

# Basic statistics of the dataset
X_train.describe()
# Out:
# Shape of X_train: (398, 30)
# Shape of y_train: (398,)
#
# Missing values:
#  mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64
#        mean radius  mean texture  mean perimeter    mean area  \
# count   398.000000    398.000000      398.000000   398.000000
# mean     14.176078     19.159171       92.256332   659.770854
# std       3.535730      4.214074       24.289529   358.865452
# min       7.691000      9.710000       48.340000   170.400000
# 25%      11.752500     16.170000       75.805000   426.175000
# 50%      13.275000     18.700000       85.980000   546.250000
# 75%      16.090000     21.555000      105.625000   797.400000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       398.000000        398.000000      398.000000           398.000000
# mean          0.095962          0.103303        0.088071             0.048440
# std           0.013766          0.051209        0.077836             0.037712
# min           0.062510          0.019380        0.000000             0.000000
# 25%           0.085550          0.063407        0.029585             0.020692
# 50%           0.094625          0.091280        0.061880             0.034110
# 75%           0.104475          0.130575        0.127075             0.073963
# max           0.163400          0.311400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst radius  \
# count     398.000000              398.000000  ...    398.000000
# mean        0.180308                0.062664  ...     16.287322
# std         0.026871                0.007248  ...      4.799691
# min         0.116700                0.049960  ...      8.678000
# 25%         0.161575                0.057665  ...     13.075000
# 50%         0.178800                0.061325  ...     14.975000
# 75%         0.195550                0.066007  ...     18.707500
# max         0.304000                0.097440  ...     36.040000
#
#        worst texture  worst perimeter   worst area  worst smoothness  \
# count     398.000000       398.000000   398.000000        398.000000
# mean       25.505553       107.363844   881.848241          0.131772
# std         6.017564        33.083204   570.753903          0.023023
# min        12.020000        54.490000   223.600000          0.081250
# 25%        21.070000        84.542500   521.550000          0.114325
# 50%        25.155000        97.745000   687.600000          0.131150
# 75%        29.410000       125.300000  1061.250000          0.146000
# max        49.540000       251.200000  4254.000000          0.218400
#
#        worst compactness  worst concavity  worst concave points  \
# count         398.000000       398.000000            398.000000
# mean            0.249086         0.268497              0.113839
# std             0.148622         0.196139              0.063886
# min             0.034320         0.000000              0.000000
# 25%             0.147325         0.116475              0.063885
# 50%             0.209250         0.226200              0.099270
# 75%             0.341600         0.384700              0.160400
# max             0.937900         0.903400              0.275600
#
#        worst symmetry  worst fractal dimension
# count      398.000000               398.000000
# mean         0.288300                 0.083537
# std          0.062318                 0.017518
# min          0.156500                 0.055040
# 25%          0.247775                 0.071155
# 50%          0.280750                 0.080165
# 75%          0.315650                 0.091745
# max          0.663800                 0.173000
#
# [8 rows x 30 columns]

# %% [markdown]
# #### Discussion points:
#
# •	Explore the dataset’s features and labels.
#
# •	Check if there are any missing values or preprocessing needed before applying TPOT.

# %% [markdown]
# ### **3. Introduction to TPOT**
#
#
# TPOT uses genetic algorithms to search for the best machine learning pipeline. It evaluates multiple pipelines, refines the best-performing ones, and finally returns the most optimized pipeline based on the given dataset.
#
# #### **Step 3.1: Initialize TPOT Classifier**
#
# We’ll use the TPOTClassifier for a binary classification task.

# %%
from tpot import TPOTClassifier

# Initialize TPOTClassifier with hyperparameters
tpot = TPOTClassifier(
    generations=5,           # Number of iterations of the genetic algorithm
    population_size=20,       # Size of the population in each generation
    verbosity=2,              # Verbosity level (higher for more detailed output)
    random_state=42,
    n_jobs=-1                 # Use all available CPU cores
)
# Out:
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %% [markdown]
# #### **Step 3.2 Fit TPOT to the Training Data**

# %%
# Fit the TPOTClassifier on the training data
tpot.fit(X_train, y_train)
# Out:
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Users/alexs/PycharmProjects/AdvancedML1/.venv/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
#
# Generation 1 - Current best internal CV score: 0.9597784810126582
#
# Generation 2 - Current best internal CV score: 0.9723734177215189
#
# Generation 3 - Current best internal CV score: 0.9723734177215189
#
# Generation 4 - Current best internal CV score: 0.9723734177215189
#
# Generation 5 - Current best internal CV score: 0.9723734177215189
#
# Best pipeline: MLPClassifier(RobustScaler(input_matrix), alpha=0.1, learning_rate_init=0.01)
# TPOTClassifier(generations=5, n_jobs=-1, population_size=20, random_state=42,
#                verbosity=2)

# %% [markdown]
# **Note:** Training TPOT may take some time, as it evaluates many pipelines across generations.

# %% [markdown]
# ### **4. Evaluating the Performance of the TPOT Model**
#
# After training, TPOT will output the best pipeline it discovered. You can then evaluate the performance of the discovered pipeline on the test data.
#
# #### **Step 4.1: Evaluate on Test Data**

# %%
# Evaluate the performance of the model on the test set
test_score = tpot.score(X_test, y_test)
print(f"Test Accuracy: {test_score * 100:.2f}%")
# Out:
# Test Accuracy: 97.66%

# %% [markdown]
# #### **Step 4.2: Export the Discovered Pipeline**
#
# TPOT will generate a Python script that defines the best pipeline discovered during the optimization process. This allows you to save and reuse the pipeline in future projects.

# %%
# Export the pipeline as a Python script
tpot.export('tpot_best_pipeline.py')

# The pipeline is saved to 'tpot_best_pipeline.py'

# %% [markdown]
# **Observation**: Recall for the minority class improves.

# %% [markdown]
# ### **5. Interpreting the Optimized Pipeline**
#
# Let’s examine the content of the exported pipeline to understand which model and preprocessing steps were selected by TPOT.
#
# #### **Step 5.1: Load the Exported Pipeline**

# %%
# Load and display the contents of the exported pipeline
with open('tpot_best_pipeline.py', 'r') as file:
    pipeline_code = file.read()
    
print(pipeline_code)
# Out:
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.neural_network import MLPClassifier
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import RobustScaler
# from tpot.export_utils import set_param_recursive
#
# # NOTE: Make sure that the outcome column is labeled 'target' in the data file
# tpot_data = pd.read_csv('PATH/TO/DATA/FILE', sep='COLUMN_SEPARATOR', dtype=np.float64)
# features = tpot_data.drop('target', axis=1)
# training_features, testing_features, training_target, testing_target = \
#             train_test_split(features, tpot_data['target'], random_state=42)
#
# # Average CV score on the training set was: 0.9723734177215189
# exported_pipeline = make_pipeline(
#     RobustScaler(),
#     MLPClassifier(alpha=0.1, learning_rate_init=0.01)
# )
# # Fix random state for all the steps in exported pipeline
# set_param_recursive(exported_pipeline.steps, 'random_state', 42)
#
# exported_pipeline.fit(training_features, training_target)
# results = exported_pipeline.predict(testing_features)

# %% [markdown]
# **Discussion:** Analyze the pipeline. Look for the preprocessing steps (e.g., scaling, imputation), the model chosen, and any hyperparameters.

# %% [markdown]
# ### **6. Visualizing the Evolution of the Genetic Algorithm**
#
# TPOT logs the performance of each generation during the genetic algorithm search. We can visualize how the best pipeline evolves over time.
#
# #### **Step 6.1: Visualize Performance Over Generations**

# %%
# Extract the scores from TPOT's internal log
generation_scores = tpot.evaluated_individuals_

# Visualize the performance of pipelines across generations
generations = list(range(1, len(generation_scores) + 1))
best_scores = [
    min(
        {k: v for k, v in generation_scores[generation].items() if isinstance(v, int)},
        key=generation_scores[generation].get
    )
    for generation in generation_scores
]

plt.plot(generations, best_scores)
plt.title("TPOT Pipeline Performance Over Generations")
plt.xlabel("Generation")
plt.ylabel("Parameters")
plt.show()

# %%
print(generation_scores)
# Out:
# {'GaussianNB(input_matrix)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 1, 'internal_cv_score': np.float64(0.9371835443037975)}, 'RandomForestClassifier(MinMaxScaler(input_matrix), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 2, 'internal_cv_score': np.float64(0.9421835443037976)}, 'XGBClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 2, 'internal_cv_score': np.float64(0.9321835443037975)}, 'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 1, 'internal_cv_score': np.float64(0.625632911392405)}, 'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=3, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 1, 'internal_cv_score': np.float64(0.9043987341772153)}, 'LinearSVC(SelectFwe(input_matrix, SelectFwe__alpha=0.036000000000000004), LinearSVC__C=0.0001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 2, 'internal_cv_score': np.float64(0.9094936708860759)}, 'MultinomialNB(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=cosine, Nystroem__n_components=3), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 2, 'internal_cv_score': np.float64(0.625632911392405)}, 'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 1, 'internal_cv_score': np.float64(0.9371202531645568)}, 'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 1, 'internal_cv_score': np.float64(0.9421835443037974)}, 'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=10, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0)': {'generation': 0, 'mutation_count': 0, 'crossover_count': 0, 'predecessor': ('ROOT',), 'operator_count': 1, 'internal_cv_score': np.float64(0.9347151898734177)}, 'BernoulliNB(SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept ...

# %%
# Parcourir chaque pipeline évalué
for pipeline_name, pipeline_details in tpot.evaluated_individuals_.items():
    if "internal_cv_score" in pipeline_details:  # Vérifie si un score est présent
        print(f"Pipeline: {pipeline_name}")
        print(f"Score: {pipeline_details['internal_cv_score']}")
        print("-" * 50)
# Out:
# Pipeline: GaussianNB(input_matrix)
# Score: 0.9371835443037975
# --------------------------------------------------
# Pipeline: RandomForestClassifier(MinMaxScaler(input_matrix), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# Score: 0.9421835443037976
# --------------------------------------------------
# Pipeline: XGBClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9321835443037975
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=3, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)
# Score: 0.9043987341772153
# --------------------------------------------------
# Pipeline: LinearSVC(SelectFwe(input_matrix, SelectFwe__alpha=0.036000000000000004), LinearSVC__C=0.0001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)
# Score: 0.9094936708860759
# --------------------------------------------------
# Pipeline: MultinomialNB(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=cosine, Nystroem__n_components=3), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9371202531645568
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9421835443037974
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=10, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0)
# Score: 0.9347151898734177
# --------------------------------------------------
# Pipeline: BernoulliNB(SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=False)
# Score: 0.8590189873417721
# --------------------------------------------------
# Pipeline: BernoulliNB(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=8, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.9548101265822784
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.01)
# Score: 0.9597784810126582
# --------------------------------------------------
# Pipeline: KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=55, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=distance)
# Score: 0.8993670886075951
# --------------------------------------------------
# Pipeline: XGBClassifier(Binarizer(input_matrix, Binarizer__threshold=0.75), XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8500000000000001, XGBClassifier__verbosity=0)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=81, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)
# Score: 0.8993037974683544
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)
# Score: 0.944746835443038
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(SelectFwe(input_matrix, SelectFwe__alpha=0.008), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=4)
# Score: 0.9171518987341771
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=4, DecisionTreeClassifier__min_samples_leaf=7, DecisionTreeClassifier__min_samples_split=13)
# Score: 0.9346518987341771
# --------------------------------------------------
# Pipeline: BernoulliNB(input_matrix, BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: XGBClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0)
# Score: 0.9321835443037976
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=6, DecisionTreeClassifier__min_samples_split=13)
# Score: 0.9321835443037976
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=10, XGBClassifier__min_child_weight=18, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0)
# Score: 0.9347151898734177
# --------------------------------------------------
# Pipeline: GaussianNB(MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False))
# Score: 0.9271518987341774
# --------------------------------------------------
# Pipeline: RandomForestClassifier(MinMaxScaler(input_matrix), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# Score: 0.9321202531645569
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9422151898734178
# --------------------------------------------------
# Pipeline: BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)
# Score: 0.9094936708860759
# --------------------------------------------------
# Pipeline: LinearSVC(SelectFwe(input_matrix, SelectFwe__alpha=0.036000000000000004), LinearSVC__C=0.0001, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)
# Score: 0.911993670886076
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.8500000000000001, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)
# Score: 0.9321835443037975
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=4)
# Score: 0.9171518987341771
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9321835443037975
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9397151898734177
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=16, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9497151898734177
# --------------------------------------------------
# Pipeline: KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=65, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)
# Score: 0.9018354430379747
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=4, DecisionTreeClassifier__min_samples_leaf=7, DecisionTreeClassifier__min_samples_split=13)
# Score: 0.9171518987341771
# --------------------------------------------------
# Pipeline: BernoulliNB(MinMaxScaler(input_matrix), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=False)
# Score: 0.41455696202531644
# --------------------------------------------------
# Pipeline: MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)
# Score: 0.8893987341772153
# --------------------------------------------------
# Pipeline: SGDClassifier(input_matrix, SGDClassifier__alpha=0.001, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)
# Score: 0.8491455696202532
# --------------------------------------------------
# Pipeline: KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=80, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)
# Score: 0.8892721518987342
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=4)
# Score: 0.9171202531645569
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)
# Score: 0.9396835443037975
# --------------------------------------------------
# Pipeline: BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.618132911392405
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=13, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9521835443037974
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9472468354430379
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9396835443037975
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=20)
# Score: 0.9171518987341771
# --------------------------------------------------
# Pipeline: BernoulliNB(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=8, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8, XGBClassifier__verbosity=0), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.9423101265822785
# --------------------------------------------------
# Pipeline: DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=19, DecisionTreeClassifier__min_samples_split=13)
# Score: 0.9171518987341771
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9371202531645568
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01)
# Score: 0.9723734177215189
# --------------------------------------------------
# Pipeline: MultinomialNB(input_matrix, MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=True)
# Score: 0.8843670886075949
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=15, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9372151898734178
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=7, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9547151898734176
# --------------------------------------------------
# Pipeline: XGBClassifier(BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9321835443037975
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=10, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0)
# Score: 0.9347151898734177
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9397151898734177
# --------------------------------------------------
# Pipeline: MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.01)
# Score: 0.8844936708860759
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.01, MLPClassifier__learning_rate_init=0.01)
# Score: 0.9598101265822784
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# Score: 0.9397151898734177
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.7000000000000001, RandomForestClassifier__min_samples_leaf=13, RandomForestClassifier__min_samples_split=9, RandomForestClassifier__n_estimators=100)
# Score: 0.9397151898734177
# --------------------------------------------------
# Pipeline: GaussianNB(MinMaxScaler(input_matrix))
# Score: 0.9321835443037975
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9397151898734177
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.01, MLPClassifier__learning_rate_init=0.001)
# Score: 0.9623101265822784
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# Score: 0.9421835443037976
# --------------------------------------------------
# Pipeline: BernoulliNB(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.2), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)
# Score: 0.9271835443037976
# --------------------------------------------------
# Pipeline: BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=False)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9422151898734178
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9447151898734176
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=13, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9547151898734176
# --------------------------------------------------
# Pipeline: XGBClassifier(StandardScaler(input_matrix), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9422151898734178
# --------------------------------------------------
# Pipeline: BernoulliNB(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=10, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8, XGBClassifier__verbosity=0), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.9448101265822786
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=11, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9572468354430379
# --------------------------------------------------
# Pipeline: MultinomialNB(input_matrix, MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=False)
# Score: 0.881867088607595
# --------------------------------------------------
# Pipeline: RandomForestClassifier(GaussianNB(input_matrix), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9422468354430379
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.65, XGBClassifier__verbosity=0)
# Score: 0.9346518987341772
# --------------------------------------------------
# Pipeline: RandomForestClassifier(MaxAbsScaler(input_matrix), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9396835443037975
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)
# Score: 0.9421835443037976
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.001)
# Score: 0.9623101265822784
# --------------------------------------------------
# Pipeline: RandomForestClassifier(GaussianNB(input_matrix), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9422468354430379
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=2, RandomForestClassifier__n_estimators=100)
# Score: 0.9421835443037976
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=13, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9472468354430379
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=8, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9396835443037975
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9246518987341773
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9648417721518987
# --------------------------------------------------
# Pipeline: RandomForestClassifier(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=8, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8, XGBClassifier__verbosity=0), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.8500000000000001, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)
# Score: 0.9473417721518986
# --------------------------------------------------
# Pipeline: BernoulliNB(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=2, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.9673101265822786
# --------------------------------------------------
# Pipeline: LinearSVC(input_matrix, LinearSVC__C=0.001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.1)
# Score: 0.911993670886076
# --------------------------------------------------
# Pipeline: MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01)
# Score: 0.8194936708860758
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.35000000000000003, XGBClassifier__verbosity=0)
# Score: 0.9246202531645569
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=4, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# Score: 0.9446835443037974
# --------------------------------------------------
# Pipeline: RandomForestClassifier(StandardScaler(input_matrix), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)
# Score: 0.944746835443038
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(ZeroCount(input_matrix)), MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.01)
# Score: 0.9673101265822783
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# Score: 0.9421835443037976
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=6, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9472468354430379
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=6, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9447151898734176
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=6, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)
# Score: 0.9472468354430379
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.5, ExtraTreesClassifier__min_samples_leaf=7, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9572151898734177
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.1)
# Score: 0.9673417721518988
# --------------------------------------------------
# Pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)
# Score: 0.9397151898734177
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=16, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9446518987341772
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(ZeroCount(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=13, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9371835443037975
# --------------------------------------------------
# Pipeline: BernoulliNB(Nystroem(input_matrix, Nystroem__gamma=0.05, Nystroem__kernel=polynomial, Nystroem__n_components=10), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.7084810126582278
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=11, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9521835443037976
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=6, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8, XGBClassifier__verbosity=0)
# Score: 0.9346835443037975
# --------------------------------------------------
# Pipeline: ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.45, ExtraTreesClassifier__min_samples_leaf=7, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)
# Score: 0.9546835443037974
# --------------------------------------------------
# Pipeline: BernoulliNB(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=2, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0), BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=False)
# Score: 0.625632911392405
# --------------------------------------------------
# Pipeline: XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=6, XGBClassifier__min_child_weight=4, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.2, XGBClassifier__verbosity=0)
# Score: 0.9195886075949368
# --------------------------------------------------
# Pipeline: BernoulliNB(XGBClassifier(GaussianNB(input_matrix), XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=2, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)
# Score: 0.9523101265822784
# --------------------------------------------------
# Pipeline: MLPClassifier(StandardScaler(input_matrix), MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01)
# Score: 0.9648417721518987
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(input_matrix), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.01)
# Score: 0.9623101265822784
# --------------------------------------------------
# Pipeline: LogisticRegression(input_matrix, LogisticRegression__C=15.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)
# Score: 0.9471202531645571
# --------------------------------------------------
# Pipeline: MLPClassifier(RobustScaler(MaxAbsScaler(input_matrix)), MLPClassifier__alpha=0.01, MLPClassifier__learning_rate_init=0.001)
# Score: 0.9623101265822784
# --------------------------------------------------

# %%
import matplotlib.pyplot as plt

# Collecter les scores et les pipelines
pipeline_names = []
scores = []

for pipeline_name, pipeline_details in tpot.evaluated_individuals_.items():
    if "internal_cv_score" in pipeline_details:
        pipeline_names.append(pipeline_name)
        scores.append(pipeline_details["internal_cv_score"])

# Tracer les scores
plt.figure(figsize=(10, 6))
plt.bar(range(len(scores)), scores)
plt.title("Scores des individus dans la population TPOT")
plt.xlabel("Pipeline Index")
plt.ylabel("Score (Validation croisée)")
plt.show()

# %% [markdown]
# ### **7. Hyperparameter Tuning with TPOT**
#
# TPOT offers several hyperparameters that can be fine-tuned to control the optimization process.
#
# #### **Step 7.1: Experiment with Different Hyperparameters**
#
# •	Try different values for generations, population_size, or mutation_rate to see how they affect the performance and speed.

# %%
# Adjust the hyperparameters and re-run TPOT
tpot_tuned = TPOTClassifier(
    generations=10,        # Increase generations for a longer search
    population_size=50,     # Increase population size for more diversity
    verbosity=2,
    random_state=42,
    n_jobs=-1
)

# Train the model
tpot_tuned.fit(X_train, y_train)

# Evaluate on test set
test_score_tuned = tpot_tuned.score(X_test, y_test)
print(f"Test Accuracy after tuning: {test_score_tuned * 100:.2f}%")
# Out:
#
# Generation 1 - Current best internal CV score: 0.9748101265822784
#
# Generation 2 - Current best internal CV score: 0.9748101265822784
#
# Generation 3 - Current best internal CV score: 0.9748101265822784
#
# Generation 4 - Current best internal CV score: 0.9748417721518987
#
# Generation 5 - Current best internal CV score: 0.9748417721518987
#
# Generation 6 - Current best internal CV score: 0.9748417721518987
#
# Generation 7 - Current best internal CV score: 0.9748417721518987
#
# Generation 8 - Current best internal CV score: 0.9748417721518987
#
# Generation 9 - Current best internal CV score: 0.9773101265822784
#
# Generation 10 - Current best internal CV score: 0.9773101265822784
#
# Best pipeline: LinearSVC(ZeroCount(RobustScaler(input_matrix)), C=0.1, dual=True, loss=hinge, penalty=l2, tol=1e-05)
# Test Accuracy after tuning: 98.83%

# %% [markdown]
# **Discussion:**
#
# •	How do different values of generations and population_size affect the final accuracy?
#
# •	Does a larger population size improve the quality of the final pipeline?

# %% [markdown]
# ### **8. Feature Importance and Interpretability**
#
# While TPOT automates the pipeline discovery process, it’s also useful to understand the importance of features in the final model.
#
# #### **Step 8.1: Feature Importance for Tree-Based Models**
#
# If the best model in the pipeline is tree-based (e.g., Random Forest or XGBoost), you can access feature importance scores.

# %%
from sklearn.ensemble import RandomForestClassifier

# Check if the best model is tree-based, then calculate feature importance
best_model = tpot.fitted_pipeline_.steps[-1][1]

if isinstance(best_model, RandomForestClassifier):
    feature_importance = best_model.feature_importances_
    # Create a DataFrame to display feature importance
    feature_importance_df = pd.DataFrame({
        'Feature': X_train.columns,
        'Importance': feature_importance
    }).sort_values(by='Importance', ascending=False)

    # Display feature importance
    print(feature_importance_df)

    # Plot feature importance
    plt.figure(figsize=(10, 6))
    plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
    plt.title('Feature Importance')
    plt.xlabel('Importance Score')
    plt.ylabel('Feature')
    plt.show()

# %% [markdown]
# **Discussion:**
#
# •	Which features are most important in the final model?
#
# •	Does this align with your intuition about the dataset?

# %% [markdown]
# ## **Homework**
#
# Try TPOT on Different Datasets:
#
# •	Download and load a new dataset, such as the Iris dataset or the Titanic dataset
#
# •	Use TPOT to optimize the machine learning pipeline.
